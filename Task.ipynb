# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'modified.csv', 'Task.ipynb', 'titanic.csv']

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 0             0            1         0      3
# 1             1            2         1      1
# 2             2            3         1      3
# 3             3            4         1      1
# 4             4            5         0      3
# ..          ...          ...       ...    ...
# 886         886          887         0      2
# 887         887          888         1      1
# 888         888          889         0      ?
# 889         889          890         1      1
# 890         890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived Pclass  \
# 0           0            1         0      3
# 1           1            2         1      1
# 2           2            3         1      3
# 3           3            4         1      1
# 4           4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 0             0            1         0      3
# 1             1            2         1      1
# 2             2            3         1      3
# 3             3            4         1      1
# 4             4            5         0      3
# ..          ...          ...       ...    ...
# 886         886          887         0      2
# 887         887          888         1      1
# 888         888          889         0      ?
# 889         889          890         1      1
# 890         890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 0             0            1         0      3
# 1             1            2         1      1
# 2             2            3         1      3
# 3             3            4         1      1
# 4             4            5         0      3
# ..          ...          ...       ...    ...
# 886         886          887         0      2
# 887         887          888         1      1
# 888         888          889         0      ?
# 889         889          890         1      1
# 890         890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
new_row = {'PassengerId':892, 'Survived':0, 'Pclass':3, 'Name':'John','Sex':'Male','Age':26,'SibSp':1,'Ticket':56246,'Fare':30,'Cabin':'','Embarked':''}

# %%
new_row
# Out:
# {'PassengerId': 892,
#  'Survived': 0,
#  'Pclass': 3,
#  'Name': 'John',
#  'Sex': 'Male',
#  'Age': 26,
#  'SibSp': 1,
#  'Ticket': 56246,
#  'Fare': 30,
#  'Cabin': '',
#  'Embarked': ''}

# %%
df = df.append(new_row,ignore_index = True)

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 0           0.0            1         0      3
# 1           1.0            2         1      1
# 2           2.0            3         1      3
# 3           3.0            4         1      1
# 4           4.0            5         0      3
# ..          ...          ...       ...    ...
# 887       887.0          888         1      1
# 888       888.0          889         0      ?
# 889       889.0          890         1      1
# 890       890.0          891         0      3
# 891         NaN          892         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
another_row = {'PassengerId':893, 'Survived':0, 'Pclass':3, 'Name':'Jane','Sex':'Male','Age':26,'SibSp':1,'Ticket':56246,'Fare':30,'Cabin':'','Embarked':''}

# %%
another_row
# Out:
# {'PassengerId': 893,
#  'Survived': 0,
#  'Pclass': 3,
#  'Name': 'Jane',
#  'Sex': 'Male',
#  'Age': 26,
#  'SibSp': 1,
#  'Ticket': 56246,
#  'Fare': 30,
#  'Cabin': '',
#  'Embarked': ''}

# %%
df = df.append(another_row,ignore_index = True)

# %%
df.tail()
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 888       888.0          889         0      ?
# 889       889.0          890         1      1
# 890       890.0          891         0      3
# 891         NaN          892         0      3
# 892         NaN          893         0      3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1    2.0
# 889                     Behr, Mr. Karl Howell    male  26.0      0    0.0
# 890                       Dooley, Mr. Patrick    male  32.0      0    0.0
# 891                                      John    Male  26.0      1    NaN
# 892                                      Jane    Male  26.0      1    NaN
#
#          Ticket   Fare Cabin Embarked
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q
# 891       56246  30.00
# 892       56246  30.00

# %%
df = df.fillna(0)

# %%
df.tail(10)
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 883       883.0          884         0      2
# 884       884.0          885         0      3
# 885       885.0          886         0      3
# 886       886.0          887         0      2
# 887       887.0          888         1      1
# 888       888.0          889         0      ?
# 889       889.0          890         1      1
# 890       890.0          891         0      3
# 891         0.0          892         0      3
# 892         0.0          893         0      3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 883             Banfield, Mr. Frederick James    male  28.0      0    0.0
# 884                    Sutehall, Mr. Henry Jr    male  25.0      0    0.0
# 885      Rice, Mrs. William (Margaret Norton)  female  39.0      0    5.0
# 886                     Montvila, Rev. Juozas    male  27.0      0    0.0
# 887              Graham, Miss. Margaret Edith  female  19.0      0    0.0
# ...

# %%
df.to_csv("modified.csv")

# %%
modified_df  = pd.read_csv("modified.csv")

# %%
modified_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  PassengerId  Survived Pclass  \
# 0             0           0.0            1         0      3
# 1             1           1.0            2         1      1
# 2             2           2.0            3         1      3
# 3             3           3.0            4         1      1
# 4             4           4.0            5         0      3
# ..          ...           ...          ...       ...    ...
# 888         888         888.0          889         0      ?
# 889         889         889.0          890         1      1
# 890         890         890.0          891         0      3
# 891         891           0.0          892         0      3
# 892         892           0.0          893         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
modified_df.tail(10)
# Out:
#      Unnamed: 0  Unnamed: 0.1  PassengerId  Survived Pclass  \
# 883         883         883.0          884         0      2
# 884         884         884.0          885         0      3
# 885         885         885.0          886         0      3
# 886         886         886.0          887         0      2
# 887         887         887.0          888         1      1
# 888         888         888.0          889         0      ?
# 889         889         889.0          890         1      1
# 890         890         890.0          891         0      3
# 891         891           0.0          892         0      3
# 892         892           0.0          893         0      3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 883             Banfield, Mr. Frederick James    male  28.0      0    0.0
# 884                    Sutehall, Mr. Henry Jr    male  25.0      0    0.0
# 885      Rice, Mrs. William (Margaret Norton)  female  39.0      0    5.0
# ...

# %%
modified_df = modified_df.fillna(0)

# %%
modified_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  PassengerId  Survived Pclass  \
# 0             0           0.0            1         0      3
# 1             1           1.0            2         1      1
# 2             2           2.0            3         1      3
# 3             3           3.0            4         1      1
# 4             4           4.0            5         0      3
# ..          ...           ...          ...       ...    ...
# 888         888         888.0          889         0      ?
# 889         889         889.0          890         1      1
# 890         890         890.0          891         0      3
# 891         891           0.0          892         0      3
# 892         892           0.0          893         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
modified_df.shape
# Out:
# (893, 14)

# %%
modified_df.isnull()
# Out:
#      Unnamed: 0  Unnamed: 0.1  PassengerId  Survived  Pclass   Name    Sex  \
# 0         False         False        False     False   False  False  False
# 1         False         False        False     False   False  False  False
# 2         False         False        False     False   False  False  False
# 3         False         False        False     False   False  False  False
# 4         False         False        False     False   False  False  False
# ..          ...           ...          ...       ...     ...    ...    ...
# 888       False         False        False     False   False  False  False
# 889       False         False        False     False   False  False  False
# 890       False         False        False     False   False  False  False
# 891       False         False        False     False   False  False  False
# 892       False         False        False     False   False  False  False
#
#        Age  SibSp  Parch  Ticket   Fare  Cabin  Embarked
# ...

# %%
modified_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# dtype: int64

# %%
modified_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  PassengerId  Survived Pclass  \
# 0             0           0.0            1         0      3
# 1             1           1.0            2         1      1
# 2             2           2.0            3         1      3
# 3             3           3.0            4         1      1
# 4             4           4.0            5         0      3
# ..          ...           ...          ...       ...    ...
# 888         888         888.0          889         0      ?
# 889         889         889.0          890         1      1
# 890         890         890.0          891         0      3
# 891         891           0.0          892         0      3
# 892         892           0.0          893         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
modified_df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1  PassengerId  Survived Pclass  \
# 0            0           0.0            1         0      3
# 1            1           1.0            2         1      1
# 2            2           2.0            3         1      3
# 3            3           3.0            4         1      1
# 4            4           4.0            5         0      3
# 5            5           5.0            6         0      3
# 6            6           6.0            7         0      1
# 7            7           7.0            8         0      3
# 8            8           8.0            9         1      3
# 9            9           9.0           10         1      2
# 10          10          10.0           11         1      3
# 11          11          11.0           12         1      1
# 12          12          12.0           13         0      3
# 13          13          13.0           14         0      3
# 14          14          14.0           15         0      3
# ...

# %%
male = modified_df[modified_df['Sex']=="male"]

# %%
male
# Out:
#      Unnamed: 0  Unnamed: 0.1  PassengerId  Survived Pclass  \
# 0             0           0.0            1         0      3
# 4             4           4.0            5         0      3
# 5             5           5.0            6         0      3
# 6             6           6.0            7         0      1
# 7             7           7.0            8         0      3
# ..          ...           ...          ...       ...    ...
# 883         883         883.0          884         0      2
# 884         884         884.0          885         0      3
# 886         886         886.0          887         0      2
# 889         889         889.0          890         1      1
# 890         890         890.0          891         0      3
#
#                                Name   Sex   Age  SibSp  Parch  \
# 0           Braund, Mr. Owen Harris  male  22.0      1    0.0
# 4          Allen, Mr. William Henry  male  35.0      0    0.0
# ...

# %%
male.count()
# Out:
# Unnamed: 0      577
# Unnamed: 0.1    577
# PassengerId     577
# Survived        577
# Pclass          577
# Name            577
# Sex             577
# Age             577
# SibSp           577
# Parch           577
# Ticket          577
# Fare            577
# Cabin           577
# Embarked        577
# dtype: int64

# %%
male.count()
# Out:
# Unnamed: 0      577
# Unnamed: 0.1    577
# PassengerId     577
# Survived        577
# Pclass          577
# Name            577
# Sex             577
# Age             577
# SibSp           577
# Parch           577
# Ticket          577
# Fare            577
# Cabin           577
# Embarked        577
# dtype: int64
